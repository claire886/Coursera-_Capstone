# %% [markdown]
# Planning a city trip according to popularity of a sight(place), days of trip and distance between attractions.

# %% [markdown]
# HTML source code are copied from https://www.google.com/travel/things-to-do/see-all with input of Portland and and display all top sights.

# %% [markdown]
# Let's import associated libraries and open our destination Portland file. We will use regular expression to extract places, rating and the number of reviews from the HTML file.

# %%
# Import libraries
import pandas as pd
import re  # regular expression

from geopy.geocoders import Nominatim  # module to convert an address into latitude and longitude values

pd.set_option('display.max_rows', 100)

# %%
# Open and read Portland to see HTML file
with open('portland_attractions.rtf', 'r', encoding='utf-8') as f:
    tosee_html = f.read()

tosee_html
# Out:
# '{\\rtf1\\ansi\\ansicpg1252\\cocoartf1671\\cocoasubrtf600\n{\\fonttbl\\f0\\fswiss\\fcharset0 Helvetica;\\f1\\fnil\\fcharset134 HiraginoSansGB-W3;}\n{\\colortbl;\\red255\\green255\\blue255;\\red0\\green0\\blue0;\\red50\\green223\\blue19;\\red28\\green33\\blue255;\n\\red203\\green218\\blue32;\\red20\\green0\\blue255;\\red209\\green200\\blue24;\\red34\\green5\\blue208;\\red207\\green161\\blue39;\n\\red43\\green117\\blue255;\\red187\\green219\\blue27;}\n{\\*\\expandedcolortbl;;\\cssrgb\\c0\\c0\\c0;\\cssrgb\\c20000\\c87843\\c8627;\\cssrgb\\c15294\\c26275\\c100000;\n\\cssrgb\\c83137\\c87059\\c15686;\\cssrgb\\c11373\\c3529\\c100000;\\cssrgb\\c85490\\c81176\\c11373;\\cssrgb\\c18431\\c16863\\c85098;\\cssrgb\\c85098\\c68627\\c19608;\n\\cssrgb\\c21176\\c55294\\c100000;\\cssrgb\\c77647\\c87059\\c13333;}\n\\margl1440\\margr1440\\vieww26820\\viewh15060\\viewkind0\n\\deftab720\n\\pard\\pardeftab720\\partightenfactor0\n\n\\f0\\fs24 \\cf0 \\expnd0\\expndtw0\\kerning0\n<div class="kQb6Eb" role="list"><div class="f4hh3d" role="listitem" jsname="Dw6TEe" data-card-id="/m/029mqm"><div class=" fCQNhc iwwqZc oBMSEc" jsname="rgNdk" data-mid="/m/029mqm" role="listitem"><div class="NnEw9 OBk50c DkSkOd" data-ved="0CBwQv2goAGoXChMIqP7Lw6Xa7AIVAAAAAB0AAAAAEHw" data-hveid="28" data-ictx="1"><div class="Ld2paf " jscontroller="Ks5NM" jsaction="x8IMsf;mouseenter:vSTZcb;NjxBQ:QyU6hf;;" data-href="/travel/things-to-do/see-all?dest_mid=/m/02frhbc&amp;dest_state_type=sattd&amp;poi_mid=/m/029mqm" data-containermid="/m/02frhbc" data-mid="/m/029mqm" \\cf3 data-title\\cf0 ="\\cf4 Pittock Mansion\\cf0 " tabindex="0" role="link"><div soy-server-key="6:qcAxOb" class="kXlUEb"><easy-img class="dBuxib SCkDmc" jsshadow=""><div class="nLGrz" style="padding-top:56.03%"></div><img class="R1Ybne YH2pd" alt="" src="https://lh6.googleusercontent.com/proxy/zudePBHwlP7-WyGuHtGU2WBTDYTJixWyV62rzhCEMqZdr_FfRZxF_WqdiqTBaU3froROYzw9U-FHU2PfZkn48kWBWyFWAmToZdWcZxwdEw1Oqq7U-2dOu_hiepNNQoZBB2lF1CwcQFsaNMtMXjfeg8CZkFCFS4HRPT4gCtRhnMAj=w464-h260-n-k-no" data-iml="606007.259999984"></easy-img></div><div class="GwjAi "><div class="rbj0Ud"><\\cf5 div class="skFvHc YmWhbc"\\cf0 >\\cf6 Pittock Mansion\\cf0 </div></div><div class="tP34jb "><\\cf7 span class="ta47le"><span aria-label="4.6 stars from 4965 reviews" \\cf0 class="Knp1ee"></span><span class="oz2bpb bVUOpb"><span class="KFi5wf" aria-hidden="true">4.6</span><div class="bVLu6d"><span class="GKZuDf r4c0Ae" style="width: 100%"><span class="DPvwYc oVmCpd koGmBf" aria-hidden="true">\n\\f1 \\uc0\\u59448 \n\\f0 </span><span class="DPvwYc oVmCpd koGmBf" aria-hidden="true">\n\\f1 \\uc0\\u59448 \n\\f0 </span><span class="DPvwYc oVmCpd koGmBf" aria-hidden="true">\n\\f1 \\uc0\\u59448 \n\\f0 </span><span class="DPvwYc oVmCpd koGmBf" aria-hidden="true">\n\\f1 \\uc0\\u59448 \n\\f0 </span><span class="DPvwYc oVmCpd koGmBf" aria-hidden="true">\n\\f1 \\uc0\\u59448 \n\\f0 </span></span><span class="EIYoWe r4c0Ae" style="width: 92.56798%"><span class="DPvwYc oVmCpd koGmBf" aria-hidden="true">\n\\f1 \\uc0\\u59448 \n\\f0 </span><span class="DPvwYc oVmCpd koGmBf" aria-hidden="true">\n\\f1 \\uc0\\u59448 \n\\f0 </span><span class="DPvwYc oVmCpd koGmBf" aria-hidden="true">\n\\f1 \\uc0\\u59448 \n\\f0 </span><span class="DPvwYc oVmCpd koGmBf" aria-hidden="true">\n\\f1 \\uc0\\u59448 \n\\f0 </span><span class="DPvwYc oVmCpd koGmBf" aria-hidden="true">\n\\f1 \\uc0\\u59448 \n\\f0 </span></span></div><span class="jdzyld" aria-hidden="true"> (4,965)</span></span></span></div><div class="nFoFM">Historic 1914 home turned into a museum</div></div></div><div class="kocnMb"><div data-id="/m/029mqm" jscontroller="fiZQ9c" jsaction="IE7JUb:vW0lqd;VowjX:LpC8sc;"></div></div></div></div></div><div class="f4hh3d" role="listitem" jsname="Dw6TEe" data-card-id="/m/06rhvq"><div class=" fCQNhc iwwqZc oBMSEc" jsname="rgNdk" data-mid="/m/06rhvq" role="listitem"><div class="NnEw9 OBk50c DkSkOd" data-ved="0CB4Qv2goAWoXChMIqP7Lw6Xa7AIVAAAAAB0AAAAAEHw" data-hveid="30" data-ictx="1"><div class= ...

# %%
# Extract strings containing name of places and rating

patn_raw = re.compile(r'YmWhbc.+reviews')

raw_matches = patn_raw.finditer(tosee_html)
raw_list_1 = []
for m in raw_matches:
    raw_list_1.append(m.group(0))

print('There are total {} places.'.format(len(raw_list_1)))
raw_list_1 = [raw.strip('YmWhbc') for raw in raw_list_1]

# There are a few places without rating that makes result messing. We'll clean up those items.
raw_list = []
for raw in raw_list_1:
    m = re.search(r'YmWhbc.+reviews', raw)
    try:
        raw_list.append(m.group())
    except:
        raw_list.append(raw)
        
print('There are total {} places with rating.'.format(len(raw_list)))
raw_list[:5]
# Out:
# There are total 93 places.
# There are total 93 places with rating.
# ['"\\cf0 >\\cf6 Pittock Mansion\\cf0 </div></div><div class="tP34jb "><\\cf7 span class="ta47le"><span aria-label="4.6 stars from 4965 reviews',
#  '\\cf0 ">\\cf10 Portland Japanese Garden\\cf0 </div></div><div class="tP34jb "><\\cf11 span class="ta47le"><span aria-label="4.5 stars from 4967 reviews',
#  '">Lan Su Chinese Garden</div></div><div class="tP34jb "><span class="ta47le"><span aria-label="4.6 stars from 2488 reviews',
#  '">OMSI</div></div><div class="tP34jb "><span class="ta47le"><span aria-label="4.5 stars from 6932 reviews',
#  '">Oregon Zoo</div></div><div class="tP34jb "><span class="ta47le"><span aria-label="4.5 stars from 14743 reviews']

# %%
# Extract name of places and put into a list
places = []
for raw in raw_list:
    m = re.search(r'[A-Z].+[a-zI](\\|<)', raw)
    try:
        places.append(m.group())
    except:
        places.append(str(raw)[0:100])
        
places[:9]
# Out:
# ['Pittock Mansion\\',
#  'Portland Japanese Garden\\',
#  'Lan Su Chinese Garden<',
#  'OMSI<',
#  'Oregon Zoo<',
#  'International Rose Test Garden<',
#  'Portland Art Museum<',
#  'Washington Park<',
#  'Pioneer Courthouse Square<']

# %%
# Reviewing the place list, one item naming 'Waterfront Renaissance..' is abnormal. Let's fixed it.
tmp = [places.index(i) for i in places if 'Waterfront Renaissance' in i]
places[tmp[0]] = 'Waterfront Renaissance Trail Vancouver WA'

places = [i.strip('\\<') for i in places]
places = [i.strip('YmWhbc">') for i in places]
places[0:9]
# Out:
# ['Pittock Mansion',
#  'Portland Japanese Garden',
#  'Lan Su Chinese Garden',
#  'OMSI',
#  'Oregon Zoo',
#  'International Rose Test Garden',
#  'Portland Art Museu',
#  'ashington Park',
#  'Pioneer Courthouse Square']

# %% [markdown]
# After examining the name of the places, I found many 'Museum' are missing the last letter 'm'. One of examples is 'Portland Art Museu'. Meanwhile, 'W' is missing from the beginning. One of examples is 'ashington Park'. Let's fix the problems.

# %%
# Fill in the missing 'm' from 'Museum'
tmp = [places.index(i) for i in places if re.search(r'Museu$', i)]
for i in tmp:
    places[i] = places[i] + 'm'

# %%
# Fill in the missing 'W' in the beginning
tmp = [places.index(i) for i in places if re.search(r'^[a-z]', i)]
for i in tmp:
    places[i] = 'W' + places[i]
places[:9]
# Out:
# ['Pittock Mansion',
#  'Portland Japanese Garden',
#  'Lan Su Chinese Garden',
#  'OMSI',
#  'Oregon Zoo',
#  'International Rose Test Garden',
#  'Portland Art Museum',
#  'Washington Park',
#  'Pioneer Courthouse Square']

# %%
# A few erratic name errors are fixed here. 
places[9] = 'Governor Tom McCall Waterfront'
places[10] = 'Hoyt Arboretum'
places[42] = 'The Freakybuttrue Peculiarium'
places[54] = 'Rice Northwest Museum of Rocks and Minerals'
places[74] = 'The Old Church'

for i, p in enumerate(places):
    print(i, p)
# Out:
# 0 Pittock Mansion
# 1 Portland Japanese Garden
# 2 Lan Su Chinese Garden
# 3 OMSI
# 4 Oregon Zoo
# 5 International Rose Test Garden
# 6 Portland Art Museum
# 7 Washington Park
# 8 Pioneer Courthouse Square
# 9 Governor Tom McCall Waterfront
# 10 Hoyt Arboretum
# 11 The Grotto
# 12 Oaks Amusement Park
# 13 Portland Saturday Market
# 14 Forest Park
# 15 Shanghai Tunnels/Portland Underground Tour
# 16 St. Johns Bridge
# 17 Portland Children's Museum
# 18 Crystal Springs Rhododendron Garden
# 19 World Forestry Center
# 20 Fort Vancouver National Historic Site | Visitor Center
# 21 South Waterfront Lower Tram Terminal
# 22 Mill Ends Park
# 23 Oregon Historical Society
# 24 Fort Vancouver National Historic Site
# 25 Tilikum Crossing Bridge
# 26 Tryon Creek State Natural Area
# 27 Powell's City of Books
# 28 Portland Audubon
# 29 Mt Tabor Park
# 30 Powell Butte
# 31 Peninsula Park
# 32 Laurelhurst Park
# 33 Witch's Castle
# 34 Wildwood Trail
# 35 Tryon Creek
# 36 Eastbank Esplanade
# 37 Keller Fountain Park
# 38 Leach Botanical Garden
# 39 Council Crest Park
# 40 Oaks Bottom Wildlife Refuge
# 41 Pearson Air Museum
# 42 The Freakybuttrue Peculiarium
# 43 Lacamas Lake
# 44 Ground Kontrol
# 45 Rocky Butte
# 46 Portland Parks &amp; Recreation
# 47 Oregon Rail Heritage Center
# 48 Kelley Point Park
# 49 Hawthorne Bridge
# 50 Steel Bridge
# 51 Marquam Nature Park
# 52 North Mississippi Avenue
# 53 Larch Mountain
# 54 Rice Northwest Museum of Rocks and Minerals
# 55 Roloff Farms
# 56 Powell Butte Nature Park
# 57 Tualatin Hills Nature Park
# 58 Sandy River Delta
# 59 Waterfront Renaissance Trail Vancouver WA
# 60 Smith and Bybee Wetlands Natural Area
# 61 Hayden Island
# 62 Southwest Council Crest Drive
# 63 South Park Blocks
# 64 Blue Lake Regional Park
# 65 Vancouver Lake
# 66 Oregon Jewish Museum and Center for Holocaust Education
# 67 Portland Oregon Temple
# 68 Pioneer Courthouse
# 69 North Clackamas Aquatic Park
# 70 Fremont Bridge
# 71 Vancouver Parks &amp; Recreation
# 72 Bella Organic Far
# 73 Vancouver Waterfront
# 74 The Old Church
# 75 Sellwood Riverfront Park
# 76 Elk Rock Garden
# 77 Jamison Square
# 78 Mount Tabor
# 79 Portland Oregon White Stag Sign
# 80 Director Park
# 81 Willamette Valley Wineries Association
# 82 Burnside Bridge
# 83 USS Blueback Submarine
# 84 Clark County Historical Museum
# 85 Skidmore Fountain
# 86 Lewis and Clark National Historical Park
# 87 Lewis and Clark State Recreation Site
# 88 Stark's Vacuum Museum
# 89 Portland Building
# 90 Cook Park
# 91 Mount Talbert Nature Park
# 92 Frenchman's Bar Regional Park

# %%
# Extract rating from raw_list
rating = []
for rate in raw_list:
    m = re.search(r'\d[.|\s]\d?\s?stars', rate)
    try:
        rating.append(m.group())
    except:
        rating.append(rate)
        
rating = [float(i.strip('stars')) for i in rating]
rating[:5]
# Out:
# [4.6, 4.5, 4.6, 4.5, 4.5]

# %%
# Extract the number of reviews from raw_list
reviews = []

for raw in raw_list:
    m = re.search(r'\d+\s(review)', raw)
    try:
        reviews.append(m.group())
    except:
        reviews.append(raw)

reviews = [int(i.strip('review')) for i in reviews]
reviews[:10]
# Out:
# [4965, 4967, 2488, 6932, 14743, 4753, 3964, 9618, 6062, 6210]

# %%
# Create dataframe for Portland attraction with rating and the number of reviews
tosee_df = pd.DataFrame(list(zip(places, rating, reviews)), columns = ['place', 'rating', 'reviews'])
tosee_df.describe()
# Out:
#           rating       reviews
# count  93.000000     93.000000
# mean    4.532258   1721.946237
# std     0.292352   3336.139947
# min     2.800000      1.000000
# 25%     4.400000    173.000000
# 50%     4.600000    598.000000
# 75%     4.700000   1650.000000
# max     5.000000  24920.000000

# %%
tosee_df
# Out:
#                                                 place  rating  reviews
# 0                                     Pittock Mansion     4.6     4965
# 66  Oregon Jewish Museum and Center for Holocaust ...     4.5       95
# 67                             Portland Oregon Temple     4.9     1360
# 68                                 Pioneer Courthouse     4.5       26
# 69                       North Clackamas Aquatic Park     4.4     1041
# 70                                     Fremont Bridge     4.4      126
# 71                   Vancouver Parks &amp; Recreation     4.3       15
# 72                                  Bella Organic Far     4.0      261
# 73                               Vancouver Waterfront     4.7     2693
# 74                        The Old Church Concert Hall     4.8      456
# 75                           Sellwood Riverfront Park     4.6     1081
# 76                                    Elk Rock Garden     4.8      223
# 77                                     Jamison Square     4.5      705
# 78                                        Mount Tabor     4.7       54
# 79                    Portland Oregon White Stag Sign     4.5      173
# 80                                      Director Park     4.4      707
# 81             Willamette Valley Wineries Association     4.3       10
# 82                                    Burnside Bridge     4.4      210
# 83                             USS Blueback Submarine     4.8      166
# 84                     Clark County Historical Museum     4.5       92
# 85                                  Skidmore Fountain     4.0      167
# 86           Lewis and Clark National Historical Park     4.7     2159
# 87              Lewis and Clark State Recreation Site     4.5      842
# 88                              Stark's Vacuum Museum     4.4        5
# 89                                  Portland Building     3.9       20
# 90                                          Cook Park     4.6     1422
# 91                          Mount Talbert Nature Park     4.5      580
# 92                      Frenchman's Bar Regional Park     4.6      312

# %% [markdown]
# Let's examine the descriptive statistics number. The range of the number of reviews is quite big, from 1 to 24920. The mean is 1721 and the standard deviation is 3336. The first quartile is 173, the median is 598 and the third quartile is 1650. Comparing the first quartil, 173, with mean, 1721, or median, 598, the places in first quartile do not get significant popularity. As a result, we will remove the places that are in the first quartile from the to-see list.

# %%
# Remove the places having less than 173 reviews.
tosee_df = tosee_df[tosee_df['reviews'] > 173]
tosee_df.reset_index(drop=True, inplace=True)
tosee_df
# Out:
#                                                 place  rating  reviews
# 0                                     Pittock Mansion     4.6     4965
# 1                            Portland Japanese Garden     4.5     4967
# 2                               Lan Su Chinese Garden     4.6     2488
# 3                                                OMSI     4.5     6932
# 4                                          Oregon Zoo     4.5    14743
# 5                      International Rose Test Garden     4.7     4753
# 6                                 Portland Art Museum     4.7     3964
# 7                                     Washington Park     4.7     9618
# 8                           Pioneer Courthouse Square     4.4     6062
# 9                      Governor Tom McCall Waterfront     4.5     6210
# 10                                     Hoyt Arboretum     4.8      978
# 11                                         The Grotto     4.7     1878
# 12                                Oaks Amusement Park     4.4     4529
# 13                           Portland Saturday Market     4.5     3845
# 14                                        Forest Park     4.8     3104
# 15         Shanghai Tunnels/Portland Underground Tour     3.7      324
# 16                                   St. Johns Bridge     4.7      514
# 17                         Portland Children's Museum     4.5     1861
# 18                Crystal Springs Rhododendron Garden     4.7     1227
# 19                              World Forestry Center     4.4      338
# 20  Fort Vancouver National Historic Site | Visito...     4.7     1217
# 21               South Waterfront Lower Tram Terminal     4.5      193
# 22                                     Mill Ends Park     4.5      633
# 23                          Oregon Historical Society     4.5      236
# 24              Fort Vancouver National Historic Site     4.7      210
# 25                            Tilikum Crossing Bridge     4.7      766
# 26                     Tryon Creek State Natural Area     4.8     1650
# 27                             Powell's City of Books     4.9    24920
# 22                                     Mill Ends Park     4.5      633
# 23                          Oregon Historical Society     4.5      236
# 24              Fort Vancouver National Historic Site     4.7      210
# 25                            Tilikum Crossing Bridge     4.7      766
# 26                     Tryon Creek State Natural Area     4.8     1650
# 27                             Powell's City of Books     4.9    24920
# 28                                   Portland Audubon     4.7      585
# 29                                      Mt Tabor Park     4.8     3930
# 30                                     Peninsula Park     4.8     2022
# 31                                   Laurelhurst Park     4.7     3035
# 32                                     Witch's Castle     4.3      563
# 33                               Keller Fountain Park     4.4      748
# 34                      The Freakybuttrue Peculiarium     4.6      452
# 35                                 Council Crest Park     4.7     1167
# 36                        Oaks Bottom Wildlife Refuge     4.6      598
# 37                                 Pearson Air Museum     4.6      248
# 38           The Freakybuttrue Peculiarium and Museum     4.2     1008
# 39                                     Ground Kontrol     4.4     4707
# 40                        Oregon Rail Heritage Center     4.7      663
# 41                                  Kelley Point Park     4.4      974
# 42                                   Hawthorne Bridge     4.5      335
# 43                                       Steel Bridge     4.5      348
# 44                                Marquam Nature Park     4.6      495
# 45      Rice Northwest Museum of Rocks &amp; Minerals     4.8      832
# 46                                       Roloff Farms     4.6      682
# 47                           Powell Butte Nature Park     4.7     2272
# 48                         Tualatin Hills Nature Park     4.7     1628
# 49                                     The Old Church     4.6     1385
# 50          Waterfront Renaissance Trail Vancouver WA     4.7      384
# 51              Smith and Bybee Wetlands Natural Area     4.4      364
# 52                                  South Park Blocks     4.5      483
# 53                            Blue Lake Regional Park     4.4     1531
# 54                             Portland Oregon Temple     4.9     1360
# 55                       North Clackamas Aquatic Park     4.4     1041
# 56                                  Bella Organic Far     4.0      261
# 57                               Vancouver Waterfront     4.7     2693
# 58                        The Old Church Concert Hall     4.8      456
# 59                           Sellwood Riverfront Park     4.6     1081
# 60                                    Elk Rock Garden     4.8      223
# 61                                     Jamison Square     4.5      705
# 62                                      Director Park     4.4      707
# 63                                    Burnside Bridge     4.4      210
# 64           Lewis and Clark National Historical Park     4.7     2159
# 65              Lewis and Clark State Recreation Site     4.5      842
# 66                                          Cook Park     4.6     1422
# 67                          Mount Talbert Nature Park     4.5      580
# 68                      Frenchman's Bar Regional Park     4.6      312

# %%
# use geopy to find latitude & longitude
geolocator = Nominatim(user_agent='portland_agent')

for i, place in enumerate(tosee_df['place']):
    if 'Vancouver' in place:
        to_find = place + ', Vancouver, WA'
    else:
        to_find = place + ', Portland, Oregon'
    
    location = geolocator.geocode(to_find)
    try:
        tosee_df.loc[i, 'latitude'] = location.latitude
        tosee_df.loc[i, 'longitude'] = location.longitude
    except:
        tosee_df.loc[i, 'latitude'] = to_find
        tosee_df.loc[i, 'longitude'] = to_find
        
# A few places that are close to Portland, but are not located in Porland. 
# We will try only add'Oregon' to find geographical coordiante.
for i, place in enumerate(tosee_df['place']):
    if tosee_df.loc[i, 'latitude'] == tosee_df.loc[i, 'longitude']:
        to_find = place + ', Oregon'
        location = geolocator.geocode(to_find)
        if location:
            tosee_df.loc[i, 'latitude'] = location.latitude
            tosee_df.loc[i, 'longitude'] = location.longitude

tosee_df
# Out:
# /Users/claire/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users
# 62                                      Director Park     4.4      707
# 63                                    Burnside Bridge     4.4      210
# 64           Lewis and Clark National Historical Park     4.7     2159
# 65              Lewis and Clark State Recreation Site     4.5      842
# 66                                          Cook Park     4.6     1422
# 67                          Mount Talbert Nature Park     4.5      580
# 68                      Frenchman's Bar Regional Park     4.6      312
#
#                                              latitude  \
# 0                                             45.5252
# 1                                             45.5187
# 2                                             45.5257
# 3                                             45.5083
# 4                                             45.5098
# 5                                             45.5191
# 6                                             45.5162
# 7                                             45.5155
# 8                                             45.5189
# 9                                             45.5204
# 10                                            45.5158
# 11                                            45.5531
# 12                                            45.4714
# 13                                            45.5227
# 14                                            45.5614
# 15  Shanghai Tunnels/Portland Underground Tour, Po...
# 16                                            45.5852
# 17                                            45.5085
# 18                                            45.4786
# 19                                            45.5108
# 20                                            45.6262
# 21                                            45.4993
# 22                                            45.5162
# 23                                            45.5159
# 24                                            45.6239
# 25                                            45.5049
# 26                                            45.4376
# 27                                            45.5233
# 28                                            45.5268
# 29                                            45.5116
# 30                                            45.5682
# 31                                            45.5211
# 32                                            45.5283
# 33                                            45.5127
# 34    The Freakybuttrue Peculiarium, Portland, Oregon
# 35                                            45.4991
# 36                                            45.4771
# 37               Pearson Air Museum, Portland, Oregon
# 38  The Freakybuttrue Peculiarium and Museum, Port...
# 39                                            45.5241
# 40                                            45.5075
# 41                                            45.6451
# 42                                            45.5132
# 43                                            45.5275
# 44                                            45.4944
# 45  Rice Northwest Museum of Rocks &amp; Minerals,...
# 46                     Roloff Farms, Portland, Oregon
# 47                                            45.4792
# 48                                             45.505
# 49                                            45.5152
# 50                                            45.6249
# 51                                            45.6198
# 52                                            45.5156
# 53                                             45.556
# 54                                            45.4254
# 55                                            45.4311
# 56                Bella Organic Far, Portland, Oregon
# 57                                            45.6288
# 58      The Old Church Concert Hall, Portland, Oregon
# 59                                            45.4673
# 60                  Elk Rock Garden, Portland, Oregon
# 61                                            45.5291
# 62                                            45.5187
# 63                                             45.523
# 64                                            46.1282
# 65                                            45.5395
# 66                                            45.3996
# 67                                            45.4263
# 68    Frenchman's Bar Regional Park, Portland, Oregon
#
#                                             longitude
# 0                                            -122.716
# 1                                            -122.708
# 2                                            -122.673
# 3                                            -122.666
# 4                                            -122.713
# 5                                            -122.705
# 6                                            -122.684
# 7                                            -122.706
# 8                                            -122.679
# 9                                             -122.67
# 10                                           -122.716
# 11                                           -122.575
# 12                                           -122.663
# 13                                            -122.67
# 14                                           -122.758
# 15  Shanghai Tunnels/Portland Underground Tour, Po...
# 16                                           -122.765
# 17                                           -122.718
# 18                                           -122.636
# 19                                           -122.718
# 20                                           -122.657
# 21                                           -122.671
# 22                                           -122.673
# 23                                           -122.682
# 24                                           -122.662
# 25                                           -122.667
# 26                                           -122.679
# 27                                           -122.682
# 28                                           -122.731
# 29                                           -122.596
# 30                                           -122.674
# 31                                           -122.627
# 32                                           -122.725
# 33                                           -122.679
# 34    The Freakybuttrue Peculiarium, Portland, Oregon
# 35                                           -122.705
# 36                                           -122.655
# 37               Pearson Air Museum, Portland, Oregon
# 38  The Freakybuttrue Peculiarium and Museum, Port...
# 39                                           -122.676
# 40                                           -122.662
# 41                                           -122.765
# 42                                           -122.671
# 43                                           -122.669
# 44                                           -122.693
# 45  Rice Northwest Museum of Rocks &amp; Minerals,...
# 46                     Roloff Farms, Portland, Oregon
# 47                                           -122.501
# 48                                            -122.84
# 49                                           -122.686
# 50                                           -122.683
# 51                                           -122.745
# 52                                           -122.683
# 53                                           -122.452
# 54                                           -122.742
# 55                                           -122.582
# 56                Bella Organic Far, Portland, Oregon
# 57                                           -122.687
# 58      The Old Church Concert Hall, Portland, Oregon
# 59                                           -122.664
# 60                  Elk Rock Garden, Portland, Oregon
# 61                                           -122.682
# 62                                           -122.681
# 63                                           -122.667
# 64                                           -123.898
# 65                                           -122.376
# 66                                           -122.774
# 67                                           -122.553
# 68    Frenchman's Bar Regional Park, Portland, Oregon

# %%
tosee_df.to_csv('portland_tosee_geocor', index=False)

# %%
# Review the places that failed to find latitude and longitude
tosee_df[tosee_df['latitude'] == tosee_df['longitude']]
# Out:
#                                             place  rating  reviews  \
# 15     Shanghai Tunnels/Portland Underground Tour     3.7      324
# 34                  The Freakybuttrue Peculiarium     4.6      452
# 37                             Pearson Air Museum     4.6      248
# 38       The Freakybuttrue Peculiarium and Museum     4.2     1008
# 45  Rice Northwest Museum of Rocks &amp; Minerals     4.8      832
# 46                                   Roloff Farms     4.6      682
# 56                              Bella Organic Far     4.0      261
# 58                    The Old Church Concert Hall     4.8      456
# 60                                Elk Rock Garden     4.8      223
# 68                  Frenchman's Bar Regional Park     4.6      312
#
#                                              latitude  \
# 15  Shanghai Tunnels/Portland Underground Tour, Po...
# 34    The Freakybuttrue Peculiarium, Portland, Oregon
# 37               Pearson Air Museum, Portland, Oregon
# 38  The Freakybuttrue Peculiarium and Museum, Port...
# 45  Rice Northwest Museum of Rocks &amp; Minerals,...
# 46                     Roloff Farms, Portland, Oregon
# 56                Bella Organic Far, Portland, Oregon
# 58      The Old Church Concert Hall, Portland, Oregon
# 60                  Elk Rock Garden, Portland, Oregon
# 68    Frenchman's Bar Regional Park, Portland, Oregon
#
#                                             longitude
# 15  Shanghai Tunnels/Portland Underground Tour, Po...
# 34    The Freakybuttrue Peculiarium, Portland, Oregon
# 37               Pearson Air Museum, Portland, Oregon
# 38  The Freakybuttrue Peculiarium and Museum, Port...
# 45  Rice Northwest Museum of Rocks &amp; Minerals,...
# 46                     Roloff Farms, Portland, Oregon
# 56                Bella Organic Far, Portland, Oregon
# 58      The Old Church Concert Hall, Portland, Oregon
# 60                  Elk Rock Garden, Portland, Oregon
# 68    Frenchman's Bar Regional Park, Portland, Oregon

# %% [markdown]
# Given more than half of the places have more than 500 reviews. I'll drop the places that are with less than 500 reviews and fail to find latitude and longitude by program from the list.

# %%
# Remove the latitude and longitude not found and the number of reviews are less than 500.

# %%
geolocator.geocode('Governor Tom McCall Waterfront, portland')
# Out:
# Location(Governor Tom McCall Waterfront Park, Chinatown, Old Town, Portland, Metro, Multnomah County, Oregon, United States of America, (45.52040275, -122.67038422190106, 0.0))

# %%
places
# Out:
# ['Pittock Mansion',
#  'Portland Japanese Garden',
#  'Lan Su Chinese Garden',
#  'OMSI',
#  'Oregon Zoo',
#  'International Rose Test Garden',
#  'Portland Art Museum',
#  'Washington Park',
#  'Pioneer Courthouse Square',
#  'Governor Tom McCall Waterfront',
#  'Hoyt Arboretum',
#  'The Grotto',
#  'Oaks Amusement Park',
#  'Portland Saturday Market',
#  'Forest Park',
#  'Shanghai Tunnels/Portland Underground Tour',
#  'St. Johns Bridge',
#  "Portland Children's Museum",
#  'Crystal Springs Rhododendron Garden',
#  'World Forestry Center',
#  'Fort Vancouver National Historic Site | Visitor Center',
#  'South Waterfront Lower Tram Terminal',
#  'Mill Ends Park',
#  'Oregon Historical Society',
#  'Fort Vancouver National Historic Site',
#  'Tilikum Crossing Bridge',
#  'Tryon Creek State Natural Area',
#  "Powell's City of Books",
#  'Portland Audubon',
#  'Mt Tabor Park',
#  'Powell Butte',
#  'Peninsula Park',
#  'Laurelhurst Park',
#  "Witch's Castle",
#  'Wildwood Trail',
#  'Tryon Creek',
#  'Eastbank Esplanade',
#  'Keller Fountain Park',
#  'The Freakybuttrue Peculiarium',
#  'Council Crest Park',
#  'Oaks Bottom Wildlife Refuge',
#  'Pearson Air Museum',
#  'The Freakybuttrue Peculiarium and Museum',
#  'Lacamas Lake',
#  'Ground Kontrol',
#  'Rice Northwest Museum of Rocks and Minerals',
#  'Portland Parks &amp; Recreation',
#  'Oregon Rail Heritage Center',
#  'Kelley Point Park',
#  'Hawthorne Bridge',
#  'Steel Bridge',
#  'Marquam Nature Park',
#  'North Mississippi Avenue',
#  'Larch Mountain',
#  'Rice Northwest Museum of Rocks &amp; Minerals',
#  'Roloff Farms',
#  'Powell Butte Nature Park',
#  'Tualatin Hills Nature Park',
#  'The Old Church',
#  'Waterfront Renaissance Trail Vancouver WA',
#  'Smith and Bybee Wetlands Natural Area',
#  'Hayden Island',
#  'Southwest Council Crest Drive',
#  'South Park Blocks',
#  'Blue Lake Regional Park',
#  'Vancouver Lake',
#  'Oregon Jewish Museum and Center for Holocaust Education',
#  'Portland Oregon Temple',
#  'Pioneer Courthouse',
#  'North Clackamas Aquatic Park',
#  'Fremont Bridge',
#  'Vancouver Parks &amp; Recreation',
#  'Bella Organic Far',
#  'Vancouver Waterfront',
#  'The Old Church Concert Hall',
#  'Sellwood Riverfront Park',
#  'Elk Rock Garden',
#  'Jamison Square',
#  'Mount Tabor',
#  'Portland Oregon White Stag Sign',
#  'Director Park',
#  'Willamette Valley Wineries Association',
#  'Burnside Bridge',
#  'USS Blueback Submarine',
#  'Clark County Historical Museum',
#  'Skidmore Fountain',
#  'Lewis and Clark National Historical Park',
#  'Lewis and Clark State Recreation Site',
#  "Stark's Vacuum Museum",
#  'Portland Building',
#  'Cook Park',
#  'Mount Talbert Nature Park',
#  "Frenchman's Bar Regional Park"]
